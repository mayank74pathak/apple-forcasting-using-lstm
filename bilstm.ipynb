# %%
import pandas as pd
df=pd.read_csv('apple.csv')

# %%
df.head(300)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-01-02   74.059998   75.150002   73.797501   75.087502   72.876099
# 1    2020-01-03   74.287498   75.144997   74.125000   74.357498   72.167610
# 2    2020-01-06   73.447502   74.989998   73.187500   74.949997   72.742653
# 3    2020-01-07   74.959999   75.224998   74.370003   74.597504   72.400536
# 4    2020-01-08   74.290001   76.110001   74.290001   75.797501   73.565193
# ..          ...         ...         ...         ...         ...         ...
# 295  2021-03-05  120.980003  121.940002  117.570000  121.419998  119.039391
# 296  2021-03-08  120.930000  121.000000  116.209999  116.360001  114.078606
# 297  2021-03-09  119.029999  122.059998  118.790001  121.089996  118.715866
# 298  2021-03-10  121.690002  122.169998  119.449997  119.980003  117.627632
# 299  2021-03-11  122.540001  123.209999  121.260002  121.959999  119.568810
#
#         Volume
# 0    135480400
# 1    146322800
# 2    118387200
# 3    108872000
# 4    132079200
# ..         ...
# 295  153766600
# 296  154376600
# 297  129525800
# 298  111943300
# 299  103026500
#
# [300 rows x 7 columns]

# %%
df1=df.reset_index()['Close']

# %%
df1.shape
# Out:
# (1006,)

# %%
import matplotlib.pyplot as plt
plt.plot(df1)

# %%
import numpy as np
df1
# Out:
# 0        75.087502
# 1        74.357498
# 2        74.949997
# 3        74.597504
# 4        75.797501
#            ...
# 1001    193.600006
# 1002    193.050003
# 1003    193.149994
# 1004    193.580002
# 1005    192.529999
# Name: Close, Length: 1006, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
#splitting the dataset from train and test split
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]

# %%
training_size,test_size
# Out:
# (653, 353)

# %%
train_data
# Out:
# array([[0.13375114],
#        [0.1286109 ],
#        [0.13278292],
#        [0.13030088],
#        [0.13875052],
#        [0.15008715],
#        [0.15131936],
#        [0.16299047],
#        [0.15545619],
#        [0.15309733],
#        [0.15996267],
#        [0.16610632],
#        [0.16230396],
#        [0.16429316],
#        [0.16698649],
#        [0.16536695],
#        [0.14889013],
#        [0.16427554],
#        [0.17598183],
#        [0.17515447],
#        [0.14987592],
#        [0.14837961],
#        [0.16631755],
#        [0.17089446],
#        [0.17751333],
#        [0.16839474],
#        [0.17107045],
#        [0.16765538],
#        [0.18101645],
#        [0.17691481],
#        [0.17705567],
#        [0.16658159],
#        [0.17471438],
#        [0.16887002],
#        [0.15610751],
#        [0.12993116],
#        [0.11215165],
#        [0.12019645],
#        [0.08652102],
#        [0.08623935],
#        [0.13104019],
#        [0.11433452],
#        [0.13795834],
#        [0.12067178],
#        [0.11382401],
#        [0.07358251],
#        [0.10732832],
#        [0.08988328],
#        [0.04200187],
#        [0.09435458],
#        [0.0314046 ],
#        [0.05015228],
#        [0.03925573],
#        [0.03592868],
#        [0.00857291],
#        [0.        ],
#        [0.03962541],
#        [0.03723134],
#        [0.05997502],
#        [0.04113931],
#        [0.05358495],
#        [0.05266956],
#        [0.02911614],
#        [0.03619272],
#        [0.02999632],
#        [0.06706921],
#        [0.06171774],
#        [0.07340647],
#        [0.0767863 ],
#        [0.08604574],
#        [0.1103385 ],
#        [0.1057264 ],
#        [0.1097048 ],
#        [0.10285703],
#        [0.0925238 ],
#        [0.07745524],
#        [0.09106274],
#        [0.08917916],
#        [0.10315631],
#        [0.1035084 ],
#        [0.09542836],
#        [0.11153558],
#        [0.12222084],
#        [0.11389443],
#        [0.12109424],
#        [0.12883976],
#        [0.13424403],
#        [0.13971869],
#        [0.15096733],
#        [0.15955782],
#        [0.15322057],
#        [0.14660165],
#        [0.14992873],
#        [0.14670726],
#        [0.15946978],
#        [0.15626599],
#        [0.16698649],
#        [0.16279686],
#        [0.16638798],
#        [0.16258562],
#        [0.16501486],
#        [0.16526133],
#        [0.16471563],
#        [0.17159859],
#        [0.17422149],
#        [0.1773549 ],
#        [0.17242595],
#        [0.18858592],
#        [0.19203618],
#        [0.21057263],
#        [0.22615171],
#        [0.19633143],
#        [0.20143643],
#        [0.20881228],
#        [0.22481383],
#        [0.22395127],
#        [0.22419775],
#        [0.22065943],
#        [0.23676659],
#        [0.25025085],
#        [0.23886141],
#        [0.24727586],
#        [0.22754239],
#        [0.24188921],
#        [0.24720543],
#        [0.24599079],
#        [0.24599079],
#        [0.2631366 ],
#        [0.26109459],
#        [0.27637439],
#        [0.27926138],
#        [0.28044078],
#        [0.27732499],
#        [0.28845039],
#        [0.29315049],
#        [0.28468322],
#        [0.28331016],
#        [0.29760416],
#        [0.28804549],
#        [0.28996426],
#        [0.25878854],
#        [0.257169  ],
#        [0.27262484],
#        [0.26165792],
#        [0.27424438],
#        [0.28234199],
#        [0.35324874],
#        [0.37210203],
#        [0.37722465],
#        [0.38002359],
#        [0.40706249],
#        [0.38741707],
#        [0.39878889],
#        [0.37518264],
#        [0.40077809],
#        [0.41486086],
#        [0.41413911],
#        [0.41202668],
#        [0.41875121],
#        [0.41977219],
#        [0.43785098],
#        [0.48076824],
#        [0.49124227],
#        [0.48397203],
#        [0.49592479],
#        [0.48527472],
#        [0.48384884],
#        [0.51365144],
#        [0.54984416],
#        [0.53026912],
#        [0.45619376],
#        [0.45675709],
#        [0.39944021],
#        [0.43112645],
#        [0.40415793],
#        [0.39366628],
#        [0.41732534],
#        [0.41859279],
#        [0.39458164],
#        [0.38197755],
#        [0.3573327 ],
#        [0.38014683],
#        [0.3923284 ],
#        [0.35930433],
#        [0.36704985],
#        [0.39563786],
#        [0.41450877],
#        [0.40838275],
#        [0.42049394],
#        [0.42739452],
#        [0.40084847],
#        [0.42535251],
#        [0.40183431],
#        [0.41535376],
#        [0.4145792 ],
#        [0.42866197],
#        [0.48097947],
#        [0.45774288],
#        [0.45837663],
#        [0.45499674],
#        [0.44309678],
#        [0.42169102],
#        [0.43246433],
#        [0.42795784],
#        [0.42007147],
#        [0.4150721 ],
#        [0.41514252],
#        [0.42605664],
#        [0.38803315],
#        [0.41704368],
#        [0.37155633],
#        [0.37092258],
#        [0.38268173],
#        [0.41443834],
#        [0.44316721],
#        [0.44077316],
#        [0.42408506],
#        [0.42162059],
#        [0.44640624],
#        [0.44443466],
#        [0.44478675],
#        [0.4521098 ],
#        [0.44570211],
#        [0.43612582],
#        [0.44042107],
#        [0.43126725],
#        [0.40669283],
#        [0.41598746],
#        [0.42204305],
#        [0.42598621],
#        [0.44330807],
#        [0.46914994],
#        [0.47168484],
#        [0.47069905],
#        [0.46584048],
#        [0.47640256],
#        [0.48083861],
#        [0.46253102],
#        [0.47281144],
#        [0.46696713],
#        [0.46253102],
#        [0.50548346],
#        [0.50499057],
#        [0.5112574 ],
#        [0.49689302],
#        [0.50794794],
#        [0.53364906],
#        [0.527171  ],
#        [0.53428276],
#        [0.56751811],
#        [0.55470273],
#        [0.54660518],
#        [0.53935256],
#        [0.51625683],
#        [0.52752298],
#        [0.4964705 ],
#        [0.52688928],
#        [0.53484608],
#        [0.51322898],
#        [0.51196158],
#        [0.52667805],
#        [0.51273613],
#        [0.50027285],
#        [0.50513142],
#        [0.53470522],
#        [0.5687855 ],
#        [0.58427664],
#        [0.61138591],
#        [0.61307588],
#        [0.60533031],
#        [0.57033462],
#        [0.53421238],
#        [0.54956255],
#        [0.55554777],
#        [0.5481543 ],
#        [0.57244705],
#        [0.56801095],
#        [0.56906722],
#        [0.56272991],
#        [0.55836428],
#        [0.55653356],
#        [0.55822343],
#        [0.54287326],
#        [0.52632596],
#        [0.51836926],
#        [0.5194958 ],
#        [0.49224568],
#        [0.49125989],
#        [0.48766876],
#        [0.45696832],
#        [0.45886952],
#        [0.50484976],
#        [0.48604928],
#        [0.4645026 ],
#        [0.45091272],
#        [0.45999612],
#        [0.42436672],
#        [0.45767245],
#        [0.44985656],
#        [0.46379847],
#        [0.45724998],
#        [0.47809248],
#        [0.48921788],
#        [0.48351437],
#        [0.45372929],
#        [0.44992693],
#        [0.47386766],
#        [0.46788249],
#        [0.45063106],
#        [0.45415175],
#        [0.45851743],
#        [0.45978488],
#        [0.44929323],
#        [0.46513635],
#        [0.47112152],
#        [0.49154155],
#        [0.49372436],
#        [0.50562432],
#        [0.52294612],
#        [0.54153538],
#        [0.52914258],
#        [0.55160451],
#        [0.53470522],
#        [0.55209745],
#        [0.54970341],
#        [0.5544915 ],
#        [0.54230993],
#        [0.54505607],
#        [0.53407152],
#        [0.55083006],
#        [0.55364657],
#        [0.5513229 ],
#        [0.54561939],
#        [0.54491521],
#        [0.53069169],
#        [0.53829629],
#        [0.50527223],
#        [0.50703263],
#        [0.5185805 ],
#        [0.52188996],
#        [0.49823084],
#        [0.49161198],
#        [0.46950198],
#        [0.48499306],
#        [0.50245566],
#        [0.49414683],
#        [0.48414807],
#        [0.48302148],
#        [0.50146987],
#        [0.48823209],
#        [0.49999119],
#        [0.49858293],
#        [0.49823084],
#        [0.48717587],
#        [0.48245815],
#        [0.48013448],
#        [0.48562676],
#        [0.47492387],
#        [0.49147112],
#        [0.49154155],
#        [0.49745629],
#        [0.50020242],
#        [0.49302023],
#        [0.50175154],
#        [0.52379105],
#        [0.51787632],
#        [0.52146738],
#        [0.53301525],
#        [0.5236503 ],
#        [0.53660643],
#        [0.5484359 ],
#        [0.54646432],
#        [0.54442237],
#        [0.54230993],
#        [0.55406903],
#        [0.5649832 ],
#        [0.56941931],
#        [0.57160212],
#        [0.59054347],
#        [0.6050487 ],
#        [0.62300426],
#        [0.6136392 ],
#        [0.62680656],
#        [0.62251131],
#        [0.63053849],
#        [0.65525371],
#        [0.650536  ],
#        [0.63581953],
#        [0.60807645],
#        [0.63412955],
#        [0.62884851],
#        [0.63870652],
#        [0.65109932],
#        [0.65412717],
#        [0.63849529],
#        [0.62589115],
#        [0.63053849],
#        [0.6320876 ],
#        [0.62969355],
#        [0.64264968],
#        [0.63976268],
#        [0.64053724],
#        [0.63405918],
#        [0.63370709],
#        [0.63025688],
#        [0.6320876 ],
#        [0.65342299],
#        [0.65490173],
#        [0.66912525],
#        [0.66257681],
#        [0.63560829],
#        [0.63800234],
#        [0.64849404],
#        [0.65919698],
#        [0.65856317],
#        [0.64969106],
#        [0.64391708],
#        [0.65138103],
#        [0.68320802],
#        [0.67412468],
#        [0.67891277],
#        [0.68693995],
#        [0.69151691],
#        [0.70834582],
#        [0.69722042],
#        [0.68989742],
#        [0.65398631],
#        [0.65807033],
#        [0.64800109],
#        [0.65440878],
#        [0.65271881],
#        [0.63349586],
#        [0.61152677],
#        [0.61497698],
#        [0.63201722],
#        [0.63891775],
#        [0.63955145],
#        [0.62863728],
#        [0.60427415],
#        [0.61075221],
#        [0.60138715],
#        [0.6094847 ],
#        [0.58476948],
#        [0.59864102],
#        [0.60490785],
#        [0.61399119],
#        [0.61124505],
#        [0.61061135],
#        [0.60145753],
#        [0.59723276],
#        [0.61730065],
#        [0.62490536],
#        [0.63694617],
#        [0.65250758],
#        [0.65602827],
#        [0.65757738],
#        [0.65201473],
#        [0.65166264],
#        [0.65645084],
#        [0.65314138],
#        [0.67933534],
#        [0.65983068],
#        [0.65391594],
#        [0.66137979],
#        [0.67173064],
#        [0.66799871],
#        [0.6702519 ],
#        [0.66433716],
#        [0.66694244],
#        [0.64659284],
#        [0.64624075],
#        [0.66116856],
#        [0.66123893],
#        [0.66828032],
#        [0.68581341],
#        [0.7166546 ],
#        [0.73552557],
#        [0.73883503],
#        [0.74158117],
#        [0.74531309],
#        [0.70919075],
#        [0.73334276],
#        [0.76897215],
#        [0.76524023],
#        [0.75812836],
#        [0.74460891],
#        [0.76911301],
#        [0.81037543],
#        [0.8378369 ],
#        [0.83417535],
#        [0.86860772],
#        [0.84248424],
#        [0.83255586],
#        [0.86755155],
#        [0.81798014],
#        [0.81009382],
#        [0.8003063 ],
#        [0.82312043],
#        [0.84178006],
#        [0.84628654],
#        [0.87480417],
#        [0.86748107],
#        [0.86811488],
#        [0.85980599],
#        [0.85536999],
#        [0.88663365],
#        [0.87036806],
#        [0.83671025],
#        [0.81614942],
#        [0.81734644],
#        [0.8174873 ],
#        [0.8378369 ],
#        [0.8410055 ],
#        [0.8174873 ],
#        [0.82368375],
#        [0.80065839],
#        [0.77552059],
#        [0.7634094 ],
#        [0.74862255],
#        [0.7430598 ],
#        [0.73010367],
#        [0.72946998],
#        [0.72616052],
#        [0.80439032],
#        [0.83572446],
#        [0.83452744],
#        [0.84318831],
#        [0.82248662],
#        [0.81889555],
#        [0.81375537],
#        [0.83607655],
#        [0.84628654],
#        [0.81699435],
#        [0.79249036],
#        [0.79418033],
#        [0.82171206],
#        [0.8200222 ],
#        [0.79418033],
#        [0.78305493],
#        [0.76207163],
#        [0.73214574],
#        [0.75094622],
#        [0.76580355],
#        [0.76770465],
#        [0.7541852 ],
#        [0.77784426],
#        [0.77552059],
#        [0.75397397],
#        [0.72672384],
#        [0.71362686],
#        [0.75242485],
#        [0.72123157],
#        [0.69454466],
#        [0.66560456],
#        [0.69707956],
#        [0.72876579],
#        [0.73601841],
#        [0.75967747],
#        [0.76953548],
#        [0.79375786],
#        [0.80354538],
#        [0.83072514],
#        [0.83530199],
#        [0.84149845],
#        [0.86515751],
#        [0.85677824],
#        [0.83452744],
#        [0.832415  ],
#        [0.86149596],
#        [0.83769604],
#        [0.81495239],
#        [0.81713521],
#        [0.80270034],
#        [0.77214076],
#        [0.78558983],
#        [0.80488316],
#        [0.76890167],
#        [0.76735267],
#        [0.783759  ],
#        [0.78256198],
#        [0.77685847],
#        [0.74425682],
#        [0.75193201],
#        [0.70912038],
#        [0.70750089],
#        [0.75728343],
#        [0.71510549],
#        [0.71728841],
#        [0.72799124],
#        [0.77404196],
#        [0.70890914],
#        [0.71250021],
#        [0.67574417],
#        [0.69299554],
#        [0.63659408],
#        [0.60885101],
#        [0.64088933],
#        [0.6298343 ],
#        [0.65588752],
#        [0.59659906],
#        [0.57216545],
#        [0.57385531],
#        [0.61272379],
#        [0.59335998],
#        [0.59448663],
#        [0.6174415 ],
#        [0.65870403],
#        [0.6530709 ],
#        [0.65215559],
#        [0.66975906],
#        [0.62870776],
#        [0.63405918],
#        [0.65215559],
#        [0.64687455],
#        [0.60941433],
#        [0.57061633],
#        [0.53364906],
#        [0.5398454 ],
#        [0.55864589],
#        [0.52083368],
#        [0.53139576],
#        [0.56174412],
#        [0.55808268],
#        [0.57864351],
#        [0.6025138 ],
#        [0.6025138 ],
#        [0.57279915],
#        [0.58540318],
#        [0.56772934],
#        [0.58329074],
#        [0.60180962],
#        [0.61138591],
#        [0.63553792],
#        [0.64039638],
#        [0.62511659],
#        [0.6320876 ],
#        [0.62948232],
#        [0.65046562],
#        [0.66243595],
#        [0.64060772],
#        [0.66828032],
#        [0.6826447 ],
#        [0.69891039],
#        [0.69003817],
#        [0.682011  ],
#        [0.67250519],
#        [0.70904989],
#        [0.71299316],
#        [0.74932663],
#        [0.74228524],
#        [0.73172316],
#        [0.77481652],
#        [0.77256322]])

# %%
import numpy 
#convert an array of values into a dataset matrix
def create_dataset(dataset,time_step=1):
    datax,datay=[],[]
    for i in range(len(dataset)-time_step-1):
        a=dataset[i:(i+time_step),0]
        datax.append(a)
        datay.append(dataset[i+time_step,0])
    return numpy.array(datax),numpy.array(datay)

# %%
#reshape into x=t,t+1,t+2,t+3 and y=t+4

time_step=100
x_train ,y_train=create_dataset(train_data,time_step)
x_test ,y_test=create_dataset(test_data,time_step)

# %%
print(x_train.shape),print(y_train.shape)
# Out:
# (552, 100)
# (552,)
# (None, None)

# %%
print(x_test.shape),print(y_test.shape)
# Out:
# (252, 100)
# (252,)
# (None, None)

# %%
#reshape input to be [samples,time steps,features]which is reaquired for lstm
x_train=x_train.reshape(x_train.shape[0],x_train.shape[1],1)
x_test=x_test.reshape(x_test.shape[0],x_test.shape[1],1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Bidirectional

# %%
model = Sequential()
model.add(Bidirectional(LSTM(50, return_sequences=True), input_shape=(100, 1)))  # First layer
model.add(Bidirectional(LSTM(50, return_sequences=True)))  # Second layer
model.add(Bidirectional(LSTM(50)))  # Third layer
model.add(Dense(1))  # Output layer
model.compile(loss='mean_squared_error', optimizer='adam')  # Compile the model
# Out:
# /Users/mayankpathak/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 100, 100)       │        20,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 100, 100)       │        60,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 100)            │        60,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 141,701 (553.52 KB)
#  Trainable params: 141,701 (553.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 235ms/step - loss: 0.1178 - val_loss: 0.0388
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.0179 - val_loss: 0.0060
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.0082 - val_loss: 0.0161
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - loss: 0.0050 - val_loss: 0.0098
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - loss: 0.0046 - val_loss: 0.0117
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - loss: 0.0039 - val_loss: 0.0077
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - loss: 0.0036 - val_loss: 0.0093
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 170ms/step - loss: 0.0034 - val_loss: 0.0057
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - loss: 0.0031 - val_loss: 0.0072
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - loss: 0.0027 - val_loss: 0.0058
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - loss: 0.0025 - val_loss: 0.0043
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - loss: 0.0021 - val_loss: 0.0038
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 275ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 279ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 268ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 268ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 272ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 272ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 279ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 310ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 0.0012 - val_loss: 9.2326e-04
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 0.0014 - val_loss: 8.9294e-04
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 315ms/step - loss: 0.0011 - val_loss: 8.5351e-04
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - loss: 0.0012 - val_loss: 8.9629e-04
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 291ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - loss: 0.0010 - val_loss: 7.8481e-04
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 0.0010 - val_loss: 8.8098e-04
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 9.7184e-04 - val_loss: 8.0500e-04
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 296ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 0.0010 - val_loss: 9.4713e-04
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 9.2370e-04 - val_loss: 8.4273e-04
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 287ms/step - loss: 0.0011 - val_loss: 9.9907e-04
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 8.4986e-04 - val_loss: 0.0011
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - loss: 8.9418e-04 - val_loss: 8.2769e-04
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 289ms/step - loss: 9.1930e-04 - val_loss: 8.3556e-04
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 290ms/step - loss: 9.5749e-04 - val_loss: 6.7889e-04
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 301ms/step - loss: 8.6714e-04 - val_loss: 8.9140e-04
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 8.2279e-04 - val_loss: 0.0013
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 0.0010 - val_loss: 8.5843e-04
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 9.2820e-04 - val_loss: 6.4957e-04
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 8.8025e-04 - val_loss: 6.4221e-04
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 287ms/step - loss: 8.3190e-04 - val_loss: 7.7482e-04
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 8.1711e-04 - val_loss: 6.4491e-04
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 8.2460e-04 - val_loss: 7.5494e-04
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 8.2538e-04 - val_loss: 8.2252e-04
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 9.5054e-04 - val_loss: 8.2519e-04
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 296ms/step - loss: 7.9016e-04 - val_loss: 7.0627e-04
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 8.6045e-04 - val_loss: 0.0013
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 288ms/step - loss: 7.9028e-04 - val_loss: 5.9109e-04
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 8.5584e-04 - val_loss: 6.1800e-04
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 280ms/step - loss: 7.3150e-04 - val_loss: 7.2762e-04
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 7.3998e-04 - val_loss: 5.6549e-04
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 291ms/step - loss: 7.3248e-04 - val_loss: 5.9040e-04
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 287ms/step - loss: 7.1638e-04 - val_loss: 5.8216e-04
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 7.3859e-04 - val_loss: 5.3886e-04
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 288ms/step - loss: 7.3099e-04 - val_loss: 5.3341e-04
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 7.0767e-04 - val_loss: 5.9052e-04
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 7.2954e-04 - val_loss: 0.0017
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 289ms/step - loss: 8.6042e-04 - val_loss: 8.6899e-04
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 7.9219e-04 - val_loss: 5.0844e-04
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 304ms/step - loss: 6.7918e-04 - val_loss: 5.1560e-04
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 287ms/step - loss: 6.9995e-04 - val_loss: 5.6548e-04
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 7.5591e-04 - val_loss: 6.8318e-04
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 6.7145e-04 - val_loss: 8.2712e-04
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 280ms/step - loss: 7.3077e-04 - val_loss: 0.0013
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 8.0756e-04 - val_loss: 5.1230e-04
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 7.0858e-04 - val_loss: 0.0011
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 280ms/step - loss: 7.6453e-04 - val_loss: 7.0163e-04
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 8.5914e-04 - val_loss: 0.0011
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 7.2487e-04 - val_loss: 6.2372e-04
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 7.7795e-04 - val_loss: 0.0010
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 8.6691e-04 - val_loss: 5.1981e-04
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 6.1487e-04 - val_loss: 8.0798e-04
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 293ms/step - loss: 6.9674e-04 - val_loss: 5.1411e-04
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 6.2155e-04 - val_loss: 0.0016
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 7.0124e-04 - val_loss: 0.0013
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 6.9414e-04 - val_loss: 6.3981e-04
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 289ms/step - loss: 7.6165e-04 - val_loss: 0.0013
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - loss: 6.1052e-04 - val_loss: 5.2814e-04
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 6.0614e-04 - val_loss: 0.0013
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 6.9632e-04 - val_loss: 5.2760e-04
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 6.6663e-04 - val_loss: 0.0020
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 295ms/step - loss: 7.8162e-04 - val_loss: 6.7507e-04
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 6.4563e-04 - val_loss: 8.2023e-04

# %%
import tensorflow as tf

# %%
###lets do the prediction and check performmance metrics
train_predict=model.predict(x_train)
test_predict=model.predict(x_test)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
#transform back to original prediction 
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
#calculate rmse performance metrices
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 137.7726742541476

# %%
#test data rmse
math.sqrt(mean_squared_error(y_test,test_predict))
# Out:
# 169.49569629491208

# %%
##plotting 
#shift train prediction for plotting
look_back=100
trainpredictplot=numpy.empty_like(df1)
trainpredictplot[:,:]=np.nan
trainpredictplot[look_back:len(train_predict)+look_back,:]=train_predict
#shift test prediction for plottting
testpredictplot=numpy.empty_like(df1)
testpredictplot[:,:]=numpy.nan
testpredictplot[len(train_predict)+(look_back*2)+1:len(df1)-1,:]=test_predict
#plot baseline and prediction
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainpredictplot)
plt.plot(testpredictplot)
plt.show()

# %%
x_input=test_data[253:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)

# %%
temp_input
# Out:
# [array([0.85973561, 0.8581865 , 0.85691899, 0.8686782 , 0.85452495,
#         0.8483286 , 0.83023219, 0.83368251, 0.84318831, 0.85297583,
#         0.88036682, 0.84699072, 0.86269298, 0.87381838, 0.90149098,
#         0.92634706, 0.92789617, 0.93909206, 0.94078192, 0.89297096,
#         0.8552995 , 0.85966513, 0.86797402, 0.8464274 , 0.83171093,
#         0.84248424, 0.83734395, 0.8581865 , 0.86593206, 0.84072389,
#         0.82973924, 0.83579483, 0.84487828, 0.81586781, 0.80509439,
#         0.80692522, 0.81058677, 0.82847184, 0.81896593, 0.82783814,
#         0.83663987, 0.85480666, 0.86536874, 0.86114387, 0.87107225,
#         0.87747993, 0.86438295, 0.86346754, 0.85241251, 0.84318831,
#         0.84051266, 0.82234587, 0.8231908 , 0.82628903, 0.80981221,
#         0.78016793, 0.78953299, 0.8041086 , 0.80748854, 0.83002095,
#         0.85536999, 0.84889182, 0.8670586 , 0.88529587, 0.8928301 ,
#         0.88945027, 0.91754533, 0.90627917, 0.92486843, 0.92888196,
#         0.9408524 , 0.94071155, 0.95310435, 0.94740084, 0.95211856,
#         0.94268313, 0.94141562, 0.94571087, 0.93845825, 0.94254227,
#         0.95162571, 0.93888072, 0.96697588, 0.95923042, 0.9729611 ,
#         0.98310072, 0.96528591, 0.97605933, 0.99894384, 1.        ,
#         0.9961977 , 0.98436812, 0.99176159, 0.97690426, 0.97584799,
#         0.96824339, 0.96437061, 0.96507468, 0.96810253, 0.96070906])]

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# [0.92858255]
# 2
# [0.92858255]
# 3
# [0.92858255]
# 4
# [0.92858255]
# 5
# [0.92858255]
# 6
# [0.92858255]
# 7
# [0.92858255]
# 8
# [0.92858255]
# 9
# [0.92858255]
# 10
# [0.92858255]
# 11
# [0.92858255]
# 12
# [0.92858255]
# 13
# [0.92858255]
# 14
# [0.92858255]
# 15
# [0.92858255]
# 16
# [0.92858255]
# 17
# [0.92858255]
# 18
# [0.92858255]
# 19
# [0.92858255]
# 20
# [0.92858255]
# 21
# [0.92858255]
# 22
# [0.92858255]
# 23
# [0.92858255]
# 24
# [0.92858255]
# 25
# [0.92858255]
# 26
# [0.92858255]
# 27
# [0.92858255]
# 28
# [0.92858255]
# 29
# [0.92858255]
# 30
# [0.92858255]
# 31
# [[0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538], [0.9285825490951538]]

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
import matplotlib.pyplot as plt

# %%
df2=df1.tolist()
df2.extend(lst_output)

# %%
plt.plot(day_new,scaler.inverse_transform(df1[906:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))
